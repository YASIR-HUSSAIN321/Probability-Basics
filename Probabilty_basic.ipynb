# %% [markdown]
# #Probabilty basic

# %% [markdown]
# \# Question 1: A die is rolled. What is the probability of getting:
#
# (a) An even number
#
# (b) A number greater than 4
# -> (a) Probability of getting an even number. {2,4,6}
# .  Favorable outcomes=3
# .  totl outcomes =6
#          P(even numbers)=3/6=1/2         answer= 1/2
#
#  (B) Probablity of getting a number greater than 4
#  Number greater than 4:   {5,6}
#   . favorable outcomes= 2
#   . Total outcomes =6
#   p(number.4)=2/6 = 1/3   Answer=1/3
#
# #   Question 2:  In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
# Question 2: In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
#
#  ->. use for formula
#  P(M & S)= n(M)=n(S)-n(M u S)
#              total student
#   . Substitute the values
#
#    P (M U S)=20+15-5=30/50=3/5
#
#    ANSWER:   3/5
# # Question 3:
#  A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
# that the next ball is also red (without replacement)?
#
#  . Frist ball is red
#  Since the first ball drawn is red, it is not replaced.
#
#   Remaining balls in the bag:
#
#   .Red balls =3-1=2
#   .Blue balls =2
#   .Total remaining balls =4
#
#  -> Probability that  that the ball is red
#
#     p(second ball is red)=Remaining red balls
#                           Remaining tatal balls
#
#        Answer  1/2
#
#     Question 4 The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
#   -> Stratified samping is the best choice because the population is divided into distinct groups
#   (stara)--boys (60%) and girls (40%).
#
# #  using Stratified sampling:
#   . You first divide the population into boys and girls.
#   . then you select sample from each group in a controlled way.
#   . this ensure equal representation of both genders in the sample.
#
# #  Simple random Sampling
# . Simple random sampling may accidentally select more boys than girls
# . It does not garuntee balanced representation, especially when population proportion are unequal.
#
#
# ->  Stratified sampling should br used because it ensure equal and fair representation of both boys and girls in the sample.
# # Question 5
# The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
#
# = 158 cm.
#
# Find the sampling error.
#
#   . Sampling Error calculation
#   . population mean height= 160cm
#   . sample mean height =158cm
# #  formula for sampling Error:
# Sampling Error= Sample Mean -population
#   Sampling Error= 158- 160= -2cm
# #  Question 6:
# The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what
# is the **standard error of the mean (SEM)** ?
#
#   Standard Error of the Mean (SEM)
#   .Population standard deviation(σ)=5000
#   .sample size(n)=100
# #  Formula for SEM:
# SEM= σ/square root n
#       Substitute the values:
# SEM=5000/square root 100 =5000/10=500
#   500 Answer
# #  Question 7:
# : In a group of 100 students:
#
# . 40 like Cricket (C)
#
# . 30 like Football (F)
#
# . 10 like both Cricket and Football
#
# Find the probability that a student likes at least one sport.
#
# -> P(C U F)= 40+30-10/100 =60/100=3/5
#   Answer 3/5b
#
# # Question 8:
#    From a deck of 52 cards, two cards are drawn **without replacement**. What is the probability that
#  both are Ace?
#
#  . tatal no of cards =52
#  .Numbers of Aces    =4
#  probality that the first card is an ace:
#    4/52
#  probility that the second card is an ace (after one Ace is drawn):
#  3/51
#  Multiply the probabilities:
#   4/52 ✖ 3/51=12/2652
#         1/221  ANSWER
# # Question 9:
#   A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the
# probability that all are non-defective?
#
#
#  .THE defectve rate is 2%, so the probability that a bulb is non-defective is:
#     1-0.02=0.98
#   if 5 bulb are chosen at random (independent selection),the probability that all are non-defective is: (0.98) squre 5
#
#         (0.98)squre5 =0.9039
#
# #   Question 10:
#   Differentiate between discrete and continuous random variables with examples.
# #  .Discrete Random Variable:
#   Let X= number of defective bulbs in a box.  possible values: 0,1,2,3,....(countable)
# #  . Continuous Random variable:
#    Let Y =time taken to complete an exam. possible values: any value between,say,0and 3hours (uncountable)
